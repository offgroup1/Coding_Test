# %%
array = [1,5,2,6,3,7,4]

commands = [[2,5,3], [4,4,1], [1,7,3]]

sorted(array[1:5])[2]

def solution(array, commands):
    answer = []
    
    
    answer = [sorted(array[lst[0] - 1: lst[1]])[lst[2] - 1] for lst in commands]

    # for lst in commands:
    #     answer.append(sorted(array[lst[0] - 1: lst[1]])[lst[2] - 1])

    return answer

solution(array, commands)
# Out:
# [5, 6, 3]
